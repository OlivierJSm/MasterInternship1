# %% [markdown]
# # Bulk Coarsening Data (UNFINISHED)
# During my presentation halfway through this project, I was informed of the cooler API having built-in support for binning coolers. This should be more clean than manually binning each file every time it is accessed. Thus, we'll bin the cell lines dataset here to the resolutions of interest (1, 2, 4 and 8 mb) to allow for future accessing.

# %% [markdown]
# ## Imports and Files

# %%
### Enabling autoreload ###
# %load_ext autoreload
# %autoreload 2

# %%
### Directories ###
root = "../../"
ramani_in_dir = '/Users/oliviersmeets/Desktop/University/Master Internship 1/Data Handling/Data/ramani_cool_files'
ramani_out_dir = root+"Data/ramani_cool_files/binned"

    # Resolution parameters
res_list = [1_000_000, 2_000_000, 4_000_000, 8_000_000]

# %%
### Imports ###
import sys
sys.path.append(root+'Scripts')
from hicdatautils import bulk_coarsen

# %% [markdown]
# ## Ramani Coarsening
